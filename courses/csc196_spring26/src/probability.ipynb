# %%
# Permutations
import numpy as np
from scipy.special import perm

N = 50
k = 5
p = perm(N, k, exact=True)
print(f"There are {p} permutations.")
# Out:
# There are 254251200 permutations.

# %%
# Combinations
import numpy as np
from scipy.special import comb

N = 50
r = 5
c = comb(N, r, exact=True)
print(f"There are {c} combinations.")
# Out:
# There are 2118760 combinations.

# %%
# Birthday problem
import numpy as np
from scipy.special import perm

N = 365 # number of days
k = 75 # Number of people registered

p = perm(N, k, exact=True)
prob_Eprime = p / (N**k)
prob_E = 1-prob_Eprime

print(f"There is a {prob_E} probability.")
# Out:
# There is a 0.9997198781738114 probability.
